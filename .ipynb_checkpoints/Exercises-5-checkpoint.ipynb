# %%
# %matplotlib inline
import pandas as pd
import seaborn as sbn
sbn.set()
import sqlalchemy
# %load_ext sql
engine = sqlalchemy.create_engine('postgresql://millbr02:@localhost/movies')
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
release_dates = pd.read_sql('release_date', engine)

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                     title  year     name   type                character     n
# 0         Suuri illusioni  1985   Homo $  actor                   Guests  22.0
# 1     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0
# 2    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 3              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 4  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN

# %%
rd = release_dates
rd
# Out:
#                                      title  year         country       date  \
# 0                    #73, Shaanthi Nivaasa  2007           India 2007-06-15
# 1            #AnonOccupy: Bio of a Villain  2015             USA 2015-11-05
# 2                                  #Beings  2015         Romania 2015-01-29
# 3                   #Ewankosau saranghaeyo  2015     Philippines 2015-01-21
# 4                                  #Horror  2015             USA 2015-11-20
# 5                            #Lucky Number  2015             USA 2015-09-01
# 6                       #Nerealnaya lyubov  2014          Russia 2014-02-13
# 7                                   #Stuck  2014          Turkey 2014-07-01
# 8                                   #Stuck  2014             USA 2014-10-10
# 9                                       #Y  2014     Philippines 2014-12-10
# 10                       #garotas: O Filme  2015          Brazil 2015-11-12
# 11                                       $  1971             USA 1971-12-17
# 12                                       $  1971    West Germany 1972-02-17
# 13                                       $  1971         Denmark 1972-03-10
# 14                                       $  1971          Sweden 1972-03-27
# 15                                       $  1971         Finland 1972-05-05
# 16                                       $  1971          France 1972-09-13
# 17                                       $  1971        Portugal 1972-09-14
# 18                                       $  1971           Japan 1972-10-07
# 19                                       $  1971          Mexico 1972-10-18
# 20                                       $  1971         Ireland 1973-01-26
# 21                                       $  1971          Turkey 1973-11-19
# 22                               $10 Raise  1935             USA 1935-05-04
# 23                       $1000 a Touchdown  1939             USA 1939-10-04
# 24                           $5,000 Reward  1918             USA 1918-05-25
# 25                          $50,000 Reward  1924              UK 1926-01-25
# 26      $50K and a Call Girl: A Love Story  2014             USA 2014-01-14
# 27                                   $9.99  2008          France 2009-04-29
# 28                                   $9.99  2008          Russia 2009-08-13
# 29                                   $9.99  2008       Australia 2009-09-17
# ...                                    ...   ...             ...        ...
# 416190             xXx: State of the Union  2005           Chile 2005-04-28
# 416191             xXx: State of the Union  2005         Croatia 2005-04-28
# 416192             xXx: State of the Union  2005  Czech Republic 2005-04-28
# 416193             xXx: State of the Union  2005         Germany 2005-04-28
# 416194             xXx: State of the Union  2005       Hong Kong 2005-04-28
# 416195             xXx: State of the Union  2005         Hungary 2005-04-28
# 416196             xXx: State of the Union  2005          Israel 2005-04-28
# 416197             xXx: State of the Union  2005      Kazakhstan 2005-04-28
# 416198             xXx: State of the Union  2005     Netherlands 2005-04-28
# 416199             xXx: State of the Union  2005        Portugal 2005-04-28
# 416200             xXx: State of the Union  2005          Russia 2005-04-28
# 416201             xXx: State of the Union  2005       Singapore 2005-04-28
# 416202             xXx: State of the Union  2005        Slovakia 2005-04-28
# 416203             xXx: State of the Union  2005        Thailand 2005-04-28
# 416204             xXx: State of the Union  2005         Austria 2005-04-29
# 416205             xXx: State of the Union  2005          Brazil 2005-04-29
# 416206             xXx: State of the Union  2005        Bulgaria 2005-04-29
# 416207             xXx: State of the Union  2005         Estonia 2005-04-29
# 416208             xXx: State of the Union  2005         Iceland 2005-04-29
# 416209             xXx: State of the Union  2005         Ireland 2005-04-29
# 416210             xXx: State of the Union  2005           Italy 2005-04-29
# 416211             xXx: State of the Union  2005          Panama 2005-04-29
# 416212             xXx: State of the Union  2005     South Korea 2005-04-29
# 416213             xXx: State of the Union  2005           Spain 2005-04-29
# 416214             xXx: State of the Union  2005              UK 2005-04-29
# 416215             xXx: State of the Union  2005             USA 2005-04-29
# 416216             xXx: State of the Union  2005          Poland 2005-06-03
# 416217             xXx: State of the Union  2005          Turkey 2005-06-03
# 416218             xXx: State of the Union  2005           China 2005-06-17
# 416219             xXx: State of the Union  2005          Greece 2005-06-24
#
#         month  day  dow
# 0           6   15    4
# 1          11    5    3
# 2           1   29    3
# 3           1   21    2
# 4          11   20    4
# 5           9    1    1
# 6           2   13    3
# 7           7    1    1
# 8          10   10    4
# 9          12   10    2
# 10         11   12    3
# 11         12   17    4
# 12          2   17    3
# 13          3   10    4
# 14          3   27    0
# 15          5    5    4
# 16          9   13    2
# 17          9   14    3
# 18         10    7    5
# 19         10   18    2
# 20          1   26    4
# 21         11   19    0
# 22          5    4    5
# 23         10    4    2
# 24          5   25    5
# 25          1   25    0
# 26          1   14    1
# 27          4   29    2
# 28          8   13    3
# 29          9   17    3
# ...       ...  ...  ...
# 416190      4   28    3
# 416191      4   28    3
# 416192      4   28    3
# 416193      4   28    3
# 416194      4   28    3
# 416195      4   28    3
# 416196      4   28    3
# 416197      4   28    3
# 416198      4   28    3
# 416199      4   28    3
# 416200      4   28    3
# 416201      4   28    3
# 416202      4   28    3
# 416203      4   28    3
# 416204      4   29    4
# 416205      4   29    4
# 416206      4   29    4
# 416207      4   29    4
# 416208      4   29    4
# 416209      4   29    4
# 416210      4   29    4
# 416211      4   29    4
# 416212      4   29    4
# 416213      4   29    4
# 416214      4   29    4
# 416215      4   29    4
# 416216      6    3    4
# 416217      6    3    4
# 416218      6   17    4
# 416219      6   24    4
#
# [416220 rows x 7 columns]

# %% [markdown]
# ### Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
rd[(rd.title.str.contains("Christmas"))&(rd.country == "USA")].groupby(["month"]).size().plot(kind="bar")

# %% [markdown]
# ### Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
rd[(rd.title.str.startswith("The Hobbit"))&(rd.country == "USA")].groupby(["month"]).size().plot(kind="bar")

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA.

# %%
rd[(rd.title.str.contains("Romance"))&(rd.country == "USA")].groupby(["dow"]).size().plot(kind="bar")

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
rd[(rd.title.str.contains("Action"))&(rd.country == "USA")].groupby(["month"]).size().plot(kind="bar")

# 2664156  actress      Dame Sybil Thorndike  23.0
# 2664157  actress                     Lilli   6.0
# 2664158  actress            Barbara Covett   1.0
# 2664159  actress                 Philomena   1.0
# 2664160  actress              Society Lady  16.0
# 2664161  actress   Lady Catherine de Bourg  20.0
# 2664162  actress                         M   4.0
# 2664163  actress              Mona Carvell   NaN
# 2664164  actress                  Bag Lady  40.0
# 2664165  actress              The Narrator   NaN
# 2664166  actress           Queen Elizabeth  12.0
# 2664167  actress                         M   2.0
# 2664168  actress                         M   NaN
# 2664169  actress                      Mary  29.0
# 2664170  actress                  Arabella   2.0
# 2664172  actress         Evelyn Greenslade   1.0
# 2664173  actress                    Aereon   4.0
# 2664174  actress            Lady Bracknell   5.0
# 2664175  actress         Evelyn Greenslade   5.0
# 2664176  actress                Agnis Hamm   3.0
# 2664178  actress                         M   6.0
# 2664179  actress                         M   9.0
# 2664180  actress  The Abbess of St. Ursula   NaN
# 2664181  actress            Queen Victoria   NaN

# %%
judidench90 = pd.merge(rd[rd.country == "USA"], a, on = ["title", "year"])

# %%
judidench90[["title", "date"]]
# Out:
#                                           title       date
# 0                                 Casino Royale 2006-11-17
# 1                                      Chocolat 2001-01-19
# 2                               Die Another Day 2002-11-22
# 3                                        Doogal 2006-02-24
# 4                                     GoldenEye 1995-11-17
# 5                                        Hamlet 1996-12-25
# 6                             Home on the Range 2004-04-02
# 7                                          Iris 2002-03-29
# 8                                      J. Edgar 2011-11-11
# 9                                  Jack & Sarah 1996-03-22
# 10                                    Jane Eyre 2011-04-22
# 11                           Ladies in Lavender 2005-05-27
# 12  Miss Peregrine's Home for Peculiar Children 2016-03-04
# 13                                    Mrs Brown 1997-07-18
# 14                       Mrs Henderson Presents 2006-02-17
# 15                         My Week with Marilyn 2011-12-23
# 16                                         Nine 2009-12-25
# 17                           Notes on a Scandal 2007-01-26
# 18                                    Philomena 2013-11-27
# 19  Pirates of the Caribbean: On Stranger Tides 2011-05-20
# 20                            Pride & Prejudice 2005-11-23
# 21                            Quantum of Solace 2008-11-14
# 22                          Shakespeare in Love 1999-01-08
# 23                                      Skyfall 2012-11-09
# 24                                      Spectre 2015-11-06
# 25                           Tea with Mussolini 1999-05-14
# 26               The Best Exotic Marigold Hotel 2012-05-25
# 27                    The Chronicles of Riddick 2004-06-11
# 28              The Importance of Being Earnest 2002-06-21
# 29        The Second Best Exotic Marigold Hotel 2015-03-06
# 30                            The Shipping News 2002-01-18
# 31                      The World Is Not Enough 1999-11-19
# 32                          Tomorrow Never Dies 1997-12-19

# %% [markdown]
# ### In which months do films with Judi Dench tend to be released in the USA?

# %%
b = cast[(cast.name == "Judi Dench")]

# %%
judidenchmovies = pd.merge(rd[rd.country == "USA"], b, on = ["title", "year"])

# %%
judidenchmovies[["title","month"]].groupby(["month"]).size().plot(kind="bar")

# %% [markdown]
# ## In November

# %% [markdown]
# ### In which months do films with Tom Cruise tend to be released in the USA?

# %%
d = cast[(cast.name == "Tom Cruise")]

# %%
tomcruisemovies = pd.merge(rd[rd.country == "USA"], d, on = ["title", "year"])

# %%
tomcruisemovies[["title","month"]].groupby(["month"]).size().plot(kind="bar")

# %% [markdown]
# ## In December
